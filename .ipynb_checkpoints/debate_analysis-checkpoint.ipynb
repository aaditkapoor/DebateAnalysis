# %% [markdown]
# # <u>Debate Analysis using Data Science</u>
# <p>
#    After getting mixed results from the news sources, I thought to analyze the VP and Presidentials debate using Data Science.<br>
#    The idea is to use YouTube comments as a medium to get the sentiment regarding the debate and getting insights from the data.<br>
#     In this analysis, we plot common phrases, common words, we also analyze sentiment and in the end for all my data science practitioners I present them a full-fledged dataset containing YouTube Comments of VP and Presidential debates
# </p>
# <hr>
#
# <footer>By Aadit Kapoor</footer>

# %% [markdown]
# # <u><b> How and Why </b></u>
#
# - Why: After getting mixed results from the news sources about the outcome of the debate, I decided to use data science to help me see the outcome of the result. With the elections around the corner, technology or to be precise analytics plays a key role in shaping our thoughts and supporting our hypothesis.
# - How: To Analyze YouTube Comments we use Python and various other NLP Libraries followed by some data visualization tools. We will use the wonders of the awesome data wrangling library known as Pandas and we hope to find some interesting insights.
#
# # Requirements
# For this project we require:
# - Python 3.8
# - Pandas
# - Scikit-Learn
# - Numpy
# - Seaborn
# - NLTK
# - Wordcloud
# - TextBlob

# %%
import pandas as pd
import requests
import json
import os
from collections import Counter
import numpy as np
from wordcloud import WordCloud
import nltk
import csv
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from textblob import TextBlob
from ipywidgets import interact
import gensim 
from nltk.tokenize import word_tokenize
import seaborn as sns
import re

URL = f"https://www.googleapis.com/youtube/v3/commentThreads?key=AIzaSyCLRprCBdl9NR5jQBocM8JspFvVhNDjY-s&textFormat=plainText&part=snippet&maxResults=100&"

# %% [markdown]
# # Creation of the Dataset
# - The dataset contains YouTube comments on the most popular/watched VP and Presidential debates. We use the YouTube Data API to get all comments (Due to the size limitation, we only get 100 comments per video). The videos have been selected through careful examination by the author, to be precise we focused on the highest number of views and the highest number of YouTube comments.

# %%
def clean_text(string):
    string = re.sub(r'[^\w\s]', '', string) 
    return ''.join(i for i in string if ord(i) < 128)

def remove_stopwords(string):
    stop_words = set(stopwords.words('english')) 
    word_tokens = word_tokenize(string) 
    filtered_sentence = [w for w in word_tokens if not w in stop_words] 
    filtered_sentence = [] 
  
    for w in word_tokens: 
        if w not in stop_words: 
            filtered_sentence.append(w) 

  
    return ' '.join(filtered_sentence)

# %% [markdown]
# # YouTube Comments Extraction
# - The following function defines the video_ids we scrap and some basic extraction code. We get our data in the form of JSON, then we perform preprocessing and ultimately combine all comments followed by the sentiment score (using TextBlob) into a DataFrame.

# %%
video_ids = {"vp_debate":['65twkjiwD90','t_G0ia3JOVs','xXE6I3gWiMc'], "prez_debate":[
                                                                         'yW8nIA33-zY','wW1lY5jFNcQ','K8Z9Kqhrh5c']}

video_id = "&videoId="
content = None

def extract_comments(resp):
    """
        Get comments from the resp (json) yt comment
    """
    com = []
    for i in resp['items']:
        com.append(i['snippet']['topLevelComment']['snippet']['textOriginal'].lower())
    return com


def get_videos_comments():
    """
        Extract video comments and store in the arrays
    """
    vp_debate_data = []
    prez_debate_data = []
    for i,j in video_ids.items():
        print("Getting for: ",i)
        for id in j:
            video_id = "&videoId=" + id
            resp = requests.get(URL+video_id)
            
            print("Length: ",len(resp.content))
            content = resp.json()
            comments = extract_comments(content)
            if i == "vp_debate":
                vp_debate_data.extend(comments)
            else:
                prez_debate_data.extend(comments)
    return vp_debate_data, prez_debate_data
class Comment:
    def __init__(self, text):
        self.text = remove_stopwords(clean_text(text))
        # set threshold as 0.5
        self.sentiment = 0 if TextBlob(self.text).sentiment.subjectivity <= 0.5 else 1
    def return_comment(self):
        return self

# %% [markdown]
# # Data Generation

# %%
class DataGenerator:
    def __init__(self, vp_debate_data, prez_debate_data):
        self.vp_data = {"comments":[], "sentiment":[]}
        self.prez_data = {"comments":[], "sentiment":[]}
        for i in vp_debate_data:
            c = Comment(i)
            self.vp_data['comments'].append(c.text)
            self.vp_data['sentiment'].append(c.sentiment)
        for i in prez_debate_data:
            c = Comment(i)
            self.prez_data['comments'].append(c.text)
            self.prez_data['sentiment'].append(c.sentiment)
        self.df_vp = pd.DataFrame(self.vp_data)
        self.df_prez = pd.DataFrame(self.prez_data)
    def return_df(self):
        print("Loaded dataframe.")
        return self.df_vp, self.df_prez
    
    # return corpus given the debate key
    # to be used for getting the commonkeywords and plotting
    def get_corpus(self, key="vp_debate"):
        corpus = []
        if key == "vp_debate":
            corpus = [i for i in self.vp_data['comments']]
        else:
            corpus = [i for i in self.prez_data['comments']]  
        
        return corpus

# %% [markdown]
# # Loading data

# %%
# load vp_debate_data and prez_debate_data
vp_debate_data, prez_debate_data = get_videos_comments()
# datagenerator
data = DataGenerator(vp_debate_data, prez_debate_data)
df_vp, df_prez = data.return_df()
# Out:
# Getting for:  vp_debate
# Length:  157522
# Length:  136739
# Length:  156290
# Getting for:  prez_debate
# Length:  141787
# Length:  141823
# Length:  140876
# Loaded dataframe.

# %%
df_prez.head()
# Out:
#                                             comments  sentiment
# 0  stop blaming president trump covid19 actually ...          0
# 1  okay listen people carefully listen people die...          1
# 2  obamacare rich everybody else get welfare medi...          0
# 3                     obamacare sucked way expensive          1
# 4  joe liar hes filthy dirty disgusting liar noth...          1

# %%
df_vp.sentiment.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df_prez.sentiment.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# - 0 stands for objectivity and 1 stands for subjectivity

# %% [markdown]
# # Another ways we can check for favourability

# %% [markdown]
# - We use different methods for candidate approval like
#     - Wordcloud
#     - Bar Plot and Frequency distribution (most common words in debates)
#     - Ability to search for a particular phrase

# %% [markdown]
# # Find Keywords
# -  Find the specified keyword (most prob top 10 words)
# - Acts on each sentence
# - Demo available

# %%
def find_keywords(word, df):
    """
        Find the specified keyword (most prob top 10 words)
        Acts on each sentence
        Add to the corresponding dataframe
        Returns: DataFrame
        
        
        Used inconjunction with get_most_common_words()
        
    """
    for i in df.comments:
        if word in i.split():
            c = Counter(i.split())
            if c[word] >= 2:
                print(f'Word is {word} that occured {c[word]} times where sentence is {i}\n')
@interact(keyword="biden", debates=['vp_debate','prez_debate'])
def run(keyword, debates):
    df = None
    if debates == "vp_debate":
        df = df_vp
    else:
        df = df_prez
    find_keywords(keyword,df)
# Out:
# Word is biden that occured 3 times where sentence is maga 2020 im toe biden eye inducked comicals arrogant racism joe biden youre black dont vote joe biden link httpsyoutubewbxcgitxwnw
#
# Word is biden that occured 2 times where sentence is criminal evidence came joe biden family recieved payouts ukrain china russia look type hunter biden laptop
#
# Word is biden that occured 2 times where sentence is president trump gods choice president god bless president trump president trump best president fulfill gods protect america support president trump fulfilling gods support biden gods enemies fulfillment biblical prophecy biden obama selfish despicable running dog accomplices ccp
#
# Word is biden that occured 2 times where sentence is trump done far black mixed racethan multiples presidents dont believe minute biden several points ahead trumpits media lies last time left media treat us like foolsand deny laugh found despicable biden son jail nowand see race presidency utter madness trump must get four yearsbecause democrats obviously need time get shit together find credible candidate
#
# Word is biden that occured 2 times where sentence is would president trump feel november 3rd election rigged google democrat operative blows whistle massive mailin voting fraud operation google biden landslide democrats cant help whispering google huge absentee vote key states favors democrats far democrats want millions fake democrat mail ballots rig election favor joe biden google dead cat gets voter registration mail google expa rep charged judicial race ballot stuffing scandal google paterson election fraud charged know google 15 election results thrown fraudulent mailin ballots google trump campaign sues nevada ballots google political calculation romney criticizes trumps mailin voting attacks google indiana woman janet reed charged election fraud indiana woman arrested charged election fraud june google expa rep charged judicial race ballot stuffing scandal google ca dem party sinking new lows harvest absentee ballots google ballotharvesting became new way steal election google kamala harris elected take gun dealers licenses away executive action google kamala harris explains plan reparations without end google sen kamala harris discusses defund police movement view time history important people get couch november 3rd vote freedom america
#
# Word is biden that occured 3 times where sentence is ask joe tough questions debate lie handlers tell millions fake democrat mailin ballots make president google democrats threaten pack supreme court ginsburg replacement rushed last 4 years every time democrats didnt get wanted threatened america vote every democrat office november 3rd google biden claims would shut country scientists recommended course faucci tell millions people getting china released wuhan virus shut entire country collapse economy google kamala harris bidens radical vp pick signals bad news american workers economic recovery google biden landslide democrats cant help whispering millions fake democrat mailin ballots give biden landslide victory november 3rd google democrat operative blows whistle massive mailin voting fraud operation
#
# Word is biden that occured 5 times where sentence is pass obamacare bill order find whats bill nancy pelosi win election order find im resigning kamala harris president cmon man joe biden google biden says aint black torn trump joe biden democrat debate joe racist kamala harris believe bidens accusers kamala harris winning democrat nomination president kamala wan na vp joe biden hell yea joe kamala harris abraham lincoln abolished slavery republican democrats plan along biden quickly resign let harris president democrats call pence disrespectful joe telling president shut man youre clown respectful office

# %% [markdown]
# # Plot WordCloud

# %%
def get_word_list(kind='vp_debate'):
    words = []
    for i in data.get_corpus(kind):
        words.extend(i.split())
    return words
    

def plot_wordcloud(kind="vp_debate"):
    words = get_word_list(kind)
    wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                min_font_size = 10).generate(' '.join(words))
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.show()



@interact(what=['vp_debate', 'prez_debate'])
def run_plot_wordcloud(what):
    plot_wordcloud(what)

# %% [markdown]
# #  Get the most common words in the corpus

# %%
# find the most common words in the corpus
def most_common(corpus):
    fd = nltk.FreqDist(corpus)
    print(fd)
    fd_t10=fd.most_common(10)
    counter = dict(fd_t10)
    # pd.Dataframe from dict to show bar plot
    df = pd.DataFrame.from_dict(counter, orient='index')
    names, values = zip(*fd_t10)
    # plot method 1
    fd.plot(10)
    # plot method two
    print("Bar Plot")
    df.plot(kind='bar')

def present(kind="vp_debate"):
    words = []
    print("Plotting data for ", kind)
    for i in data.get_corpus(kind):
        words.extend(i.split())
    most_common(words)

@interact(kind=['vp_debate', 'prez_debate'])
def run_present(kind):
    present(kind)
# Out:
# Plotting data for  vp_debate
# <FreqDist with 2215 samples and 4851 outcomes>
# Bar Plot
# Plotting data for  prez_debate
# <FreqDist with 1629 samples and 3502 outcomes>
# Bar Plot

# %% [markdown]
# # Download Dataset

# %% [markdown]
# - Download the dataset from kaggle
